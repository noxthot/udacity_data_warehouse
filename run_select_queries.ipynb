# %%
import configparser
import psycopg2
from sql_queries import select_queries


def select_tables(cur, conn):
    for query in select_queries:
        cur.execute(query)
        
        print('\n#####################')
        print(query)
        
        for table in cur.fetchall():
            print(table)

def main():
    config = configparser.ConfigParser()
    config.read('dwh.cfg')

    conn = psycopg2.connect("host={} dbname={} user={} password={} port={}".format(*config['CLUSTER'].values()))
    cur = conn.cursor()
    
    select_tables(cur, conn)

    conn.close()

if __name__ == "__main__":
    main()
# Out:
# #####################
#
# SELECT * FROM songplays LIMIT 20;
#
# (59, datetime.datetime(9999, 10, 30, 11, 9, 56), 49, 'paid', 'SOBONKR12A58A7A7E0', 'AR5E44Z1187B9A1D74', 1041, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (123, datetime.datetime(9999, 4, 3, 16, 19, 56), 6, 'free', 'SOBONKR12A58A7A7E0', 'AR5E44Z1187B9A1D74', 847, 'Atlanta-Sandy Springs-Roswell, GA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0')
# (187, datetime.datetime(9999, 3, 17, 21, 39, 56), 30, 'paid', 'SOBONKR12A58A7A7E0', 'AR5E44Z1187B9A1D74', 324, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (251, datetime.datetime(9999, 12, 9, 23, 33, 16), 50, 'free', 'SOBONKR12A58A7A7E0', 'AR5E44Z1187B9A1D74', 156, 'New Haven-Milford, CT', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (315, datetime.datetime(9999, 11, 12, 13, 36, 36), 80, 'paid', 'SOSDZFY12A8C143718', 'AR748W61187B9B6AB8', 611, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (379, datetime.datetime(9999, 10, 6, 20, 16, 36), 70, 'paid', 'SOKUCXB12A6D4FAC0C', 'ARHO39G1187FB4E31B', 113, 'San Antonio-New Braunfels, TX', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (443, datetime.datetime(9999, 7, 10, 0, 59, 56), 49, 'free', 'SOUNZHU12A8AE47481', 'AR37SX11187FB3E164', 405, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (507, datetime.datetime(9999, 5, 9, 10, 23, 16), 36, 'paid', 'SOEMXXF12A6D4F932C', 'ARI4S0E1187B9B06C0', 461, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (571, datetime.datetime(9999, 7, 19, 10, 3, 16), 73, 'paid', 'SOYRFUE12AB0183E5C', 'ARTYXEZ1187FB54560', 294, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (31, datetime.datetime(9999, 5, 26, 10, 29, 56), 67, 'free', 'SOCHRXB12A8AE48069', 'ARTDQRC1187FB4EFD4', 414, 'Nashville-Davidson--Murfreesboro--Franklin, TN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (95, datetime.datetime(9999, 5, 25, 23, 6, 36), 25, 'paid', 'SOQTPLM12B0B809575', 'ARS8GNX1187B9B5141', 594, 'Marinette, WI-MI', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (159, datetime.datetime(9999, 7, 21, 3, 29, 56), 49, 'paid', 'SOWGZFG12A8151AF41', 'ARC8CQZ1187B98DECA', 576, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (223, datetime.datetime(9999, 3, 30, 0, 56, 36), 36, 'free', 'SOLNAVA12AB01842E0', 'AR15R2V1187B9A9803', 392, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (52, datetime.datetime(9999, 11, 9, 18, 19, 56), 92, 'free', 'SONQBUB12A6D4F8ED0', 'ARFCUN31187B9AD578', 938, 'Palestine, TX', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0')
# (116, datetime.datetime(9999, 12, 7, 7, 13, 16), 80, 'paid', 'SOTJXIH12A6D228208', 'ARG85O51187B99CC1D', 574, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (180, datetime.datetime(9999, 11, 15, 4, 23, 16), 80, 'paid', 'SOTNWCI12AAF3B2028', 'ARS54I31187FB46721', 611, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (244, datetime.datetime(9999, 11, 26, 17, 23, 16), 73, 'paid', 'SONQLSC12AB01816E0', 'ARQFJDL1187B98BF86', 518, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (16, datetime.datetime(9999, 2, 15, 4, 26, 36), 81, 'free', 'SOQDMXT12A6D4F8255', 'ART5MUE1187B98C961', 317, 'Las Cruces, NM', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (80, datetime.datetime(9999, 4, 4, 12, 53, 16), 80, 'paid', 'SOAOJYY12A58A7B2F9', 'ARFVYJI1187B9B8E13', 416, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (144, datetime.datetime(9999, 2, 18, 17, 49, 56), 100, 'free', 'SOHTKMO12AB01843B0', 'AR5EYTL1187B98EDA0', 595, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
#
# #####################
#
# SELECT * FROM users LIMIT 20;
#
# (55, 'Martin', 'Johnson', 'M', 'free')
# (88, 'Mohammad', 'Rodriguez', 'M', 'paid')
# (2, 'Jizelle', 'Benjamin', 'F', 'free')
# (49, 'Chloe', 'Cuevas', 'F', 'paid')
# (83, 'Stefany', 'White', 'F', 'free')
# (24, 'Layla', 'Griffin', 'F', 'paid')
# (9, 'Wyatt', 'Scott', 'M', 'free')
# (78, 'Chloe', 'Roth', 'F', 'free')
# (96, 'Cierra', 'Finley', 'F', 'free')
# (40, 'Tucker', 'Garrison', 'M', 'free')
# (20, 'Aiden', 'Ramirez', 'M', 'paid')
# (70, 'Jaleah', 'Hayes', 'F', 'paid')
# (66, 'Kevin', 'Arellano', 'M', 'free')
# (81, 'Sienna', 'Colon', 'F', 'free')
# (52, 'Theodore', 'Smith', 'M', 'free')
# (95, 'Sara', 'Johnson', 'F', 'paid')
# (89, 'Kynnedi', 'Sanchez', 'F', 'free')
# (25, 'Jayden', 'Graves', 'M', 'paid')
# (27, 'Carlos', 'Carter', 'M', 'free')
# (71, 'Ayleen', 'Wise', 'F', 'free')
#
# #####################
#
# SELECT * FROM songs LIMIT 20;
#
# ('SOLBIIE12AB0184DFC', 'Cooler Than You', 'AR1GYND1187B9A9CD3', 1998, Decimal('124'))
# ('SORPTVX12AB0182843', 'Filles_ Flics_ Descentes', 'ARHL4JG1187FB400D6', 2001, Decimal('240'))
# ('SOBCOMW12AB01868ED', 'Powershifter', 'AR4549W1187B9AF46F', 2010, Decimal('231'))
# ('SOBCEWR12A8C136FC0', 'Mutate With Me', 'ARO0AKN1187B9A1B84', 1996, Decimal('133'))
# ('SOVPCNZ12A67AD94E4', 'You Could Change My Mind', 'AR2WN631187B99DA0B', 0, Decimal('225'))
# ('SOLZJSW12AB0180826', 'Heads Kicked In', 'ARXYVR61187B9A8E41', 2003, Decimal('159'))
# ('SOVKMUR12A67AE23FA', "Let's Make Rock", 'ARIFAA91187FB37EA6', 2004, Decimal('243'))
# ('SOYNBJL12A58A7771A', 'Barracuda', 'ARB91LI1187B9B0D97', 2006, Decimal('231'))
# ('SOBDTSF12AB0187D73', 'Bad Sign', 'AR49OYY1187B9AD57D', 1992, Decimal('205'))
# ('SOQFZHG12AB018B9FE', 'Throught Adjuster', 'ARCIQB81187B9A44F3', 2005, Decimal('98'))
# ('SOIBAKV12A8C142CE7', 'Jimi Baby', 'AR5BX3Y1187FB39E93', 0, Decimal('118'))
# ('SOHTKWQ12A8C13FEC3', 'Colours', 'ARNCDQT1187FB4F2E6', 2006, Decimal('373'))
# ('SOPGWWX12AB017D4E7', 'Take me to this place', 'AR4X7481187B999045', 2004, Decimal('325'))
# ('SOYOHPX12A8C135B81', 'If My Mind Is Evil', 'ARORX9K1187FB3DC3F', 1989, Decimal('303'))
# ('SOINBCU12A6D4F94C0', 'Human Cannonball', 'ARV1JVD1187B9AD195', 1995, Decimal('190'))
# ('SOLWQFA12AB01899E8', 'Give It What U Got', 'ARXG6L11187FB5695E', 2007, Decimal('260'))
# ('SOYDOBR12AB01834F6', 'When They Are Gone (for Tim)', 'ARI25MJ1187FB3E1B0', 2009, Decimal('207'))
# ('SOYHZWP12A58A7C176', 'Shake Some Action', 'ARWD82K1187B98CFF2', 1995, Decimal('263'))
# ('SOMLSMH12A6310DF24', 'Building Steam With A Grain Of Salt', 'ARME7101187FB3ECDD', 1996, Decimal('399'))
# ('SOCQIQG12AB017D8FB', 'Amar Y Amar', 'ARGVL871187B9A2CAB', 2009, Decimal('204'))
#
# #####################
#
# SELECT * FROM artists LIMIT 20;
#
# ('ARADNLR124549A36DE', 'A.B. Quintanilla III Y Los Kumbia All Starz', '', None, None)
# ('ARCXDYN123526A0A71', 'Pedro Khima', '', None, None)
# ('AR2AEIR1187B9B9FC9', 'Amebix', 'England', Decimal('52'), Decimal('-1'))
# ('ARNWVN41187B9A51BB', 'Scanners', 'London/Stroud', Decimal('51'), Decimal('0'))
# ('ARKWT6J1187B98ED50', 'Móveis Coloniais de Acaju', '', None, None)
# ('ARFBMAG119B866940F', 'Infant Sorrow', '', None, None)
# ('ARR5CEB1187FB5A3FF', 'Restless Heart', '', None, None)
# ('ARI8JQ01187B99FB50', 'Edvin Marton', '', None, None)
# ('ARYONFX1187B9B5795', 'Cristian Vogel', 'Chile', Decimal('-35'), Decimal('-71'))
# ('AR32ML41187FB36D9A', 'Justice', 'Luton, Bedfordshire, England', None, None)
# ('ARJHPM91187B9B86C5', 'This Will Destroy You', 'Austin TX', None, None)
# ('ARTB3OO1187FB49BDA', 'Elton John', 'Pinner, Middlesex, England', Decimal('51'), Decimal('0'))
# ('ARCS9JN1187B9AF569', 'In Slaughter Natives', '', None, None)
# ('AR9WE2M1187FB46290', 'Wisdom In Chains', '', None, None)
# ('ARBVX4Y1187FB42E5E', 'The Housemartins', 'Hull, England', None, None)
# ('ARTJH1Z1187B98E784', 'Joy Williams', '', None, None)
# ('ARIA1UE1187FB52A1F', 'Justin Hayward', 'UK', Decimal('54'), Decimal('-2'))
# ('AR31G891187FB3892D', 'Laid Back', 'Denmark', Decimal('56'), Decimal('9'))
# ('ARYEBQC1187FB5ACD9', 'The Devin Townsend Band', '', None, None)
# ('ARJ0AL61187B9A3F27', 'Katie Melua', 'Georgia', None, None)
#
# #####################
#
# SELECT * FROM time LIMIT 20;
#
# (datetime.datetime(9999, 2, 8, 0, 46, 36), 0, 8, 6, 2, 50843, 0)
# (datetime.datetime(9999, 10, 19, 22, 13, 16), 22, 19, 42, 10, 50878, 3)
# (datetime.datetime(9999, 10, 27, 5, 23, 16), 5, 27, 44, 10, 50843, 2)
# (datetime.datetime(9999, 11, 18, 0, 26, 36), 0, 18, 47, 11, 50842, 2)
# (datetime.datetime(9999, 7, 27, 10, 36, 36), 10, 27, 31, 7, 50860, 2)
# (datetime.datetime(9999, 4, 9, 23, 13, 16), 23, 9, 14, 4, 50873, 0)
# (datetime.datetime(9999, 5, 10, 3, 59, 56), 3, 10, 20, 5, 50860, 1)
# (datetime.datetime(9999, 10, 30, 11, 9, 56), 11, 30, 44, 10, 50881, 4)
# (datetime.datetime(9999, 5, 5, 12, 36, 36), 12, 5, 19, 5, 50860, 3)
# (datetime.datetime(9999, 1, 6, 13, 36, 36), 13, 6, 2, 1, 50882, 2)
# (datetime.datetime(9999, 1, 22, 5, 29, 56), 5, 22, 4, 1, 50829, 1)
# (datetime.datetime(9999, 11, 26, 23, 9, 56), 23, 26, 48, 11, 50881, 3)
# (datetime.datetime(9999, 8, 24, 6, 39, 56), 6, 24, 35, 8, 50820, 1)
# (datetime.datetime(9999, 11, 15, 4, 23, 16), 4, 15, 46, 11, 50842, 6)
# (datetime.datetime(9999, 12, 11, 20, 29, 56), 20, 11, 50, 12, 50879, 1)
# (datetime.datetime(9999, 7, 21, 7, 16, 36), 7, 21, 30, 7, 50826, 2)
# (datetime.datetime(9999, 7, 25, 12, 3, 16), 12, 25, 30, 7, 50876, 6)
# (datetime.datetime(9999, 11, 1, 20, 13, 16), 20, 1, 44, 11, 50859, 6)
# (datetime.datetime(9999, 1, 1, 2, 19, 56), 2, 1, 1, 1, 50859, 3)
# (datetime.datetime(9999, 10, 15, 17, 23, 16), 17, 15, 41, 10, 50879, 0)
